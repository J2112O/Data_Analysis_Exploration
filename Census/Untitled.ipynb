# %%
import pandas as pd

# %%
csv = pd.read_csv('acs2015_county_data.csv')

# %%
csv.shape
# Out:
# (3220, 37)

# %%
csv.head(3)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         73.6        20.9           5.5         0.0           7.6
# 1         81.5        12.3           5.8         0.4           7.5
# 2         71.8        20.8           7.3         0.1          17.6
#
# [3 rows x 37 columns]

# %%
csv.TotalPop
# Out:
# 0        55221
# 1       195121
# 2        26932
# 3        22604
# 4        57710
# 5        10678
# 6        20354
# 7       116648
# 8        34079
# 9        26008
# 10       43819
# 11       13395
# 12       25070
# 13       13537
# 14       15002
# 15       50884
# 16       54444
# 17       12865
# 18       11027
# 19       37886
# 20       13938
# 21       80965
# 22       49866
# 23       42154
# 24       71068
# 25       80763
# 26       37935
# 27      103766
# 28       16896
# 29       31634
#          ...
# 3190     11701
# 3191     83418
# 3192     38815
# 3193     32294
# 3194     26804
# 3195     29751
# 3196     22595
# 3197     18441
# 3198     22770
# 3199    156054
# 3200     25205
# 3201     14841
# 3202     53029
# 3203     24307
# 3204     30114
# 3205     34125
# 3206    371400
# 3207     39778
# 3208     40471
# 3209     22913
# 3210     74603
# 3211     85242
# 3212     71886
# 3213     31474
# 3214     39319
# 3215     56858
# 3216      9130
# ...

# %%
csv.head(3)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
# 1     0.6      ...        1.0          1.4         3.9         26.4     85953
# 2     0.2      ...        1.8          1.5         1.6         24.1      8597
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         73.6        20.9           5.5         0.0           7.6
# 1         81.5        12.3           5.8         0.4           7.5
# 2         71.8        20.8           7.3         0.1          17.6
#
# [3 rows x 37 columns]

# %%
csv.State.unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming', 'Puerto Rico'],
#       dtype=object)

# %%
csv.State.unique().value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-b711d349eab9> in <module>()
# ----> 1 csv.State.unique().value_counts()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'value_counts'

# %%
csv.State.value_counts()
# Out:
# Texas                   254
# Georgia                 159
# Virginia                133
# Kentucky                120
# Missouri                115
# Kansas                  105
# Illinois                102
# North Carolina          100
# Iowa                     99
# Tennessee                95
# Nebraska                 93
# Indiana                  92
# Ohio                     88
# Minnesota                87
# Michigan                 83
# Mississippi              82
# Puerto Rico              78
# Oklahoma                 77
# Arkansas                 75
# Wisconsin                72
# Pennsylvania             67
# Florida                  67
# Alabama                  67
# South Dakota             66
# Colorado                 64
# Louisiana                64
# New York                 62
# California               58
# Montana                  56
# West Virginia            55
# North Dakota             53
# South Carolina           46
# Idaho                    44
# ...

# %%
csv.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b18d85797a9f> in <module>()
# ----> 1 csv.dtype
#
# ~/Data_Analysis_Exploration/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
csv.head(1)
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
#
#    Native      ...       Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4      ...        0.5          1.3         1.8         26.5     23986
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0         73.6        20.9           5.5         0.0           7.6
#
# [1 rows x 37 columns]

# %%
csv.WorkAtHome.dtype
